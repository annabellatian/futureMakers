# %% [markdown]
# <a href="https://colab.research.google.com/github/annabellatian/mit-futuremakers/blob/main/autoencoderTutorial/autoencoderTutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras import layers

# This is the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# This is our input image
input_img = keras.Input(shape=(784,))
# "encoded" is the encoded representation of the input
encoded = layers.Dense(encoding_dim, activation='relu')(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = layers.Dense(784, activation='sigmoid')(encoded)

# This model maps an input to its reconstruction
autoencoder = keras.Model(input_img, decoded)

# %%
# This model maps an input to its encoded representation
encoder = keras.Model(input_img, encoded)

# %%
# This is our encoded (32-dimensional) input
encoded_input = keras.Input(shape=(encoding_dim,))
# Retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# Create the decoder model
decoder = keras.Model(encoded_input, decoder_layer(encoded_input))

# %%
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
from keras.datasets import mnist
import numpy as np
(x_train, _), (x_test, _) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/50
# 235/235 [==============================] - 15s 5ms/step - loss: 0.3805 - val_loss: 0.1917
# Epoch 2/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1813 - val_loss: 0.1548
# Epoch 3/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1501 - val_loss: 0.1340
# Epoch 4/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1318 - val_loss: 0.1220
# Epoch 5/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1212 - val_loss: 0.1139
# Epoch 6/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1136 - val_loss: 0.1080
# Epoch 7/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1081 - val_loss: 0.1037
# Epoch 8/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1038 - val_loss: 0.1005
# Epoch 9/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1007 - val_loss: 0.0979
# Epoch 10/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0985 - val_loss: 0.0960
# Epoch 11/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0968 - val_loss: 0.0947
# Epoch 12/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0958 - val_loss: 0.0940
# Epoch 13/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0952 - val_loss: 0.0936
# Epoch 14/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0947 - val_loss: 0.0932
# Epoch 15/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0944 - val_loss: 0.0929
# Epoch 16/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0940 - val_loss: 0.0926
# Epoch 17/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0938 - val_loss: 0.0925
# Epoch 18/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0937 - val_loss: 0.0925
# Epoch 19/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0935 - val_loss: 0.0923
# Epoch 20/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0936 - val_loss: 0.0922
# Epoch 21/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0934 - val_loss: 0.0922
# Epoch 22/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0933 - val_loss: 0.0921
# Epoch 23/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0933 - val_loss: 0.0920
# Epoch 24/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0933 - val_loss: 0.0920
# Epoch 25/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0932 - val_loss: 0.0919
# Epoch 26/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0929 - val_loss: 0.0919
# Epoch 27/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0927 - val_loss: 0.0919
# Epoch 28/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0931 - val_loss: 0.0919
# Epoch 29/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0930 - val_loss: 0.0918
# Epoch 30/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0930 - val_loss: 0.0917
# Epoch 31/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0931 - val_loss: 0.0918
# Epoch 32/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0927 - val_loss: 0.0917
# Epoch 33/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0928 - val_loss: 0.0918
# Epoch 34/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0927 - val_loss: 0.0918
# Epoch 35/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0927 - val_loss: 0.0917
# Epoch 36/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 37/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0928 - val_loss: 0.0916
# Epoch 38/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 39/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0928 - val_loss: 0.0916
# Epoch 40/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0925 - val_loss: 0.0916
# Epoch 41/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0929 - val_loss: 0.0916
# Epoch 42/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0930 - val_loss: 0.0915
# Epoch 43/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0925 - val_loss: 0.0916
# Epoch 44/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0926 - val_loss: 0.0915
# Epoch 45/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0928 - val_loss: 0.0914
# Epoch 46/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0927 - val_loss: 0.0915
# Epoch 47/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0926 - val_loss: 0.0915
# Epoch 48/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0925 - val_loss: 0.0915
# Epoch 49/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0924 - val_loss: 0.0915
# Epoch 50/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0926 - val_loss: 0.0915

# %%
# Encode and decode some digits
# Note that we take them from the *test* set
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

# %%
# Use Matplotlib (don't ask)
import matplotlib.pyplot as plt

n = 10  # How many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
from keras import regularizers

encoding_dim = 32

input_img = keras.Input(shape=(784,))
# Add a Dense layer with a L1 activity regularizer
encoded = layers.Dense(encoding_dim, activation='relu',
                activity_regularizer=regularizers.l1(10e-5))(input_img)
decoded = layers.Dense(784, activation='sigmoid')(encoded)

autoencoder = keras.Model(input_img, decoded)

# %% [markdown]
# Deep Autoencoder

# %%
input_img = keras.Input(shape=(784,))
encoded = layers.Dense(128, activation='relu')(input_img)
encoded = layers.Dense(64, activation='relu')(encoded)
encoded = layers.Dense(32, activation='relu')(encoded)

decoded = layers.Dense(64, activation='relu')(encoded)
decoded = layers.Dense(128, activation='relu')(decoded)
decoded = layers.Dense(784, activation='sigmoid')(decoded)

# %%
autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

autoencoder.fit(x_train, x_train,
                epochs=100,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/100
# 235/235 [==============================] - 2s 5ms/step - loss: 0.3367 - val_loss: 0.1645
# Epoch 2/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1579 - val_loss: 0.1391
# Epoch 3/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1361 - val_loss: 0.1258
# Epoch 4/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1249 - val_loss: 0.1176
# Epoch 5/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1168 - val_loss: 0.1115
# Epoch 6/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1121 - val_loss: 0.1079
# Epoch 7/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1088 - val_loss: 0.1054
# Epoch 8/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1062 - val_loss: 0.1034
# Epoch 9/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1042 - val_loss: 0.1020
# Epoch 10/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1024 - val_loss: 0.1002
# Epoch 11/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1010 - val_loss: 0.0989
# Epoch 12/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0995 - val_loss: 0.0974
# Epoch 13/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0980 - val_loss: 0.0961
# Epoch 14/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0972 - val_loss: 0.0951
# Epoch 15/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0962 - val_loss: 0.0951
# Epoch 16/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0954 - val_loss: 0.0940
# Epoch 17/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0948 - val_loss: 0.0937
# Epoch 18/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0941 - val_loss: 0.0926
# Epoch 19/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0932 - val_loss: 0.0921
# Epoch 20/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0926 - val_loss: 0.0916
# Epoch 21/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0924 - val_loss: 0.0913
# Epoch 22/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0919 - val_loss: 0.0906
# Epoch 23/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0914 - val_loss: 0.0903
# Epoch 24/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0907 - val_loss: 0.0897
# Epoch 25/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0903 - val_loss: 0.0892
# Epoch 26/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0900 - val_loss: 0.0889
# Epoch 27/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0896 - val_loss: 0.0887
# Epoch 28/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0891 - val_loss: 0.0883
# Epoch 29/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0886 - val_loss: 0.0880
# Epoch 30/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0884 - val_loss: 0.0877
# Epoch 31/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0880 - val_loss: 0.0873
# Epoch 32/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0880 - val_loss: 0.0870
# Epoch 33/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0876 - val_loss: 0.0866
# Epoch 34/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0872 - val_loss: 0.0866
# Epoch 35/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0871 - val_loss: 0.0863
# Epoch 36/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0867 - val_loss: 0.0858
# Epoch 37/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0865 - val_loss: 0.0861
# Epoch 38/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0864 - val_loss: 0.0857
# Epoch 39/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0864 - val_loss: 0.0855
# Epoch 40/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0861 - val_loss: 0.0857
# Epoch 41/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0859 - val_loss: 0.0855
# Epoch 42/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0858 - val_loss: 0.0852
# Epoch 43/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0858 - val_loss: 0.0853
# Epoch 44/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0855 - val_loss: 0.0848
# Epoch 45/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0852 - val_loss: 0.0849
# Epoch 46/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0853 - val_loss: 0.0850
# Epoch 47/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0852 - val_loss: 0.0848
# Epoch 48/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0850 - val_loss: 0.0847
# Epoch 49/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0849 - val_loss: 0.0845
# Epoch 50/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0848 - val_loss: 0.0844
# Epoch 51/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0848 - val_loss: 0.0842
# Epoch 52/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0848 - val_loss: 0.0841
# Epoch 53/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0844 - val_loss: 0.0843
# Epoch 54/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0846 - val_loss: 0.0840
# Epoch 55/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0846 - val_loss: 0.0843
# Epoch 56/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0842 - val_loss: 0.0838
# Epoch 57/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0844 - val_loss: 0.0838
# Epoch 58/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0842 - val_loss: 0.0837
# Epoch 59/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0844 - val_loss: 0.0841
# Epoch 60/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0841 - val_loss: 0.0839
# Epoch 61/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0842 - val_loss: 0.0837
# Epoch 62/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0838 - val_loss: 0.0836
# Epoch 63/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0839 - val_loss: 0.0834
# Epoch 64/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0838 - val_loss: 0.0833
# Epoch 65/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0839 - val_loss: 0.0834
# Epoch 66/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0837 - val_loss: 0.0832
# Epoch 67/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0837 - val_loss: 0.0834
# Epoch 68/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0836 - val_loss: 0.0830
# Epoch 69/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0833 - val_loss: 0.0828
# Epoch 70/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0833 - val_loss: 0.0828
# Epoch 71/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0830 - val_loss: 0.0827
# Epoch 72/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0830 - val_loss: 0.0825
# Epoch 73/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0828 - val_loss: 0.0826
# Epoch 74/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0828 - val_loss: 0.0825
# Epoch 75/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0827 - val_loss: 0.0827
# Epoch 76/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0827 - val_loss: 0.0823
# Epoch 77/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0826 - val_loss: 0.0822
# Epoch 78/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0825 - val_loss: 0.0823
# Epoch 79/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0826 - val_loss: 0.0820
# Epoch 80/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0824 - val_loss: 0.0823
# Epoch 81/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0824 - val_loss: 0.0821
# Epoch 82/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0823 - val_loss: 0.0819
# Epoch 83/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0822 - val_loss: 0.0820
# Epoch 84/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0821 - val_loss: 0.0821
# Epoch 85/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0824 - val_loss: 0.0819
# Epoch 86/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0822 - val_loss: 0.0819
# Epoch 87/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0823 - val_loss: 0.0819
# Epoch 88/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0821 - val_loss: 0.0818
# Epoch 89/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0821 - val_loss: 0.0819
# Epoch 90/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0822 - val_loss: 0.0816
# Epoch 91/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0819 - val_loss: 0.0817
# Epoch 92/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0819 - val_loss: 0.0817
# Epoch 93/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0819 - val_loss: 0.0816
# Epoch 94/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0818 - val_loss: 0.0817
# Epoch 95/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0819 - val_loss: 0.0817
# Epoch 96/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0816 - val_loss: 0.0815
# Epoch 97/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0817 - val_loss: 0.0816
# Epoch 98/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0818 - val_loss: 0.0817
# Epoch 99/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0816 - val_loss: 0.0816
# Epoch 100/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0817 - val_loss: 0.0815

# %% [markdown]
# Convolutional Autoencoder

# %%
import keras
from keras import layers

input_img = keras.Input(shape=(28, 28, 1))

x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(16, (3, 3), activation='relu')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
from keras.datasets import mnist
import numpy as np

(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

# %%
from keras.callbacks import TensorBoard

autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test, x_test),
                callbacks=[TensorBoard(log_dir='/tmp/autoencoder')])
# Out:
# Epoch 1/50
# 469/469 [==============================] - 34s 9ms/step - loss: 0.3489 - val_loss: 0.1459
# Epoch 2/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1402 - val_loss: 0.1264
# Epoch 3/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1245 - val_loss: 0.1173
# Epoch 4/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1169 - val_loss: 0.1121
# Epoch 5/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1126 - val_loss: 0.1091
# Epoch 6/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1095 - val_loss: 0.1063
# Epoch 7/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1072 - val_loss: 0.1046
# Epoch 8/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1055 - val_loss: 0.1034
# Epoch 9/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1044 - val_loss: 0.1020
# Epoch 10/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1029 - val_loss: 0.1010
# Epoch 11/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1016 - val_loss: 0.1003
# Epoch 12/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1009 - val_loss: 0.0992
# Epoch 13/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1001 - val_loss: 0.0993
# Epoch 14/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0996 - val_loss: 0.0979
# Epoch 15/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0990 - val_loss: 0.0975
# Epoch 16/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0986 - val_loss: 0.0970
# Epoch 17/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0983 - val_loss: 0.0970
# Epoch 18/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0977 - val_loss: 0.0962
# Epoch 19/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0973 - val_loss: 0.0958
# Epoch 20/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0967 - val_loss: 0.0957
# Epoch 21/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0964 - val_loss: 0.0955
# Epoch 22/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0964 - val_loss: 0.0948
# Epoch 23/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0961 - val_loss: 0.0948
# Epoch 24/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0957 - val_loss: 0.0942
# Epoch 25/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0952 - val_loss: 0.0940
# Epoch 26/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0950 - val_loss: 0.0936
# Epoch 27/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0948 - val_loss: 0.0936
# Epoch 28/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0942 - val_loss: 0.0932
# Epoch 29/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0944 - val_loss: 0.0931
# Epoch 30/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0940 - val_loss: 0.0927
# Epoch 31/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0938 - val_loss: 0.0928
# Epoch 32/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0933 - val_loss: 0.0922
# Epoch 33/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0931 - val_loss: 0.0919
# Epoch 34/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0930 - val_loss: 0.0918
# Epoch 35/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 36/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0926 - val_loss: 0.0914
# Epoch 37/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0925 - val_loss: 0.0913
# Epoch 38/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0923 - val_loss: 0.0910
# Epoch 39/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0921 - val_loss: 0.0910
# Epoch 40/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0921 - val_loss: 0.0907
# Epoch 41/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0918 - val_loss: 0.0907
# Epoch 42/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0915 - val_loss: 0.0903
# Epoch 43/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0916 - val_loss: 0.0902
# Epoch 44/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0914 - val_loss: 0.0902
# Epoch 45/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0913 - val_loss: 0.0900
# Epoch 46/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0911 - val_loss: 0.0901
# Epoch 47/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0910 - val_loss: 0.0896
# Epoch 48/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0908 - val_loss: 0.0897
# Epoch 49/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0907 - val_loss: 0.0897
# Epoch 50/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0904 - val_loss: 0.0895

# %%
decoded_imgs = autoencoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 4))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
encoder = keras.Model(input_img, encoded)
encoded_imgs = encoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 8))
for i in range(1, n + 1):
    ax = plt.subplot(1, n, i)
    plt.imshow(encoded_imgs[i].reshape((4, 4 * 8)).T)
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# Application to Image Denoising

# %%
from keras.datasets import mnist
import numpy as np

(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape) 
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape) 

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# %%
n = 10
plt.figure(figsize=(20, 2))
for i in range(1, n + 1):
    ax = plt.subplot(1, n, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
input_img = keras.Input(shape=(28, 28, 1))

x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)

# At this point the representation is (7, 7, 32)

x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
autoencoder.fit(x_train_noisy, x_train,
                epochs=100,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test_noisy, x_test),
                callbacks=[TensorBoard(log_dir='/tmp/tb', histogram_freq=0, write_graph=False)])
# Out:
# Epoch 1/100
# 469/469 [==============================] - 5s 9ms/step - loss: 0.2524 - val_loss: 0.1184
# Epoch 2/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1171 - val_loss: 0.1102
# Epoch 3/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1104 - val_loss: 0.1068
# Epoch 4/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1066 - val_loss: 0.1039
# Epoch 5/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1043 - val_loss: 0.1017
# Epoch 6/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1022 - val_loss: 0.1003
# Epoch 7/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1010 - val_loss: 0.0991
# Epoch 8/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1003 - val_loss: 0.0985
# Epoch 9/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0993 - val_loss: 0.0982
# Epoch 10/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0986 - val_loss: 0.0975
# Epoch 11/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0979 - val_loss: 0.0970
# Epoch 12/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0976 - val_loss: 0.0966
# Epoch 13/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0972 - val_loss: 0.0963
# Epoch 14/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0970 - val_loss: 0.0961
# Epoch 15/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0968 - val_loss: 0.0960
# Epoch 16/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0966 - val_loss: 0.0956
# Epoch 17/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0964 - val_loss: 0.0960
# Epoch 18/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0962 - val_loss: 0.0960
# Epoch 19/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0962 - val_loss: 0.0954
# Epoch 20/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0958 - val_loss: 0.0951
# Epoch 21/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0956 - val_loss: 0.0956
# Epoch 22/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0955 - val_loss: 0.0948
# Epoch 23/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0953 - val_loss: 0.0948
# Epoch 24/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0954 - val_loss: 0.0948
# Epoch 25/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0951 - val_loss: 0.0946
# Epoch 26/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0952 - val_loss: 0.0945
# Epoch 27/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0950 - val_loss: 0.0948
# Epoch 28/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0948 - val_loss: 0.0945
# Epoch 29/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0947 - val_loss: 0.0943
# Epoch 30/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0947 - val_loss: 0.0946
# Epoch 31/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0947 - val_loss: 0.0942
# Epoch 32/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0947 - val_loss: 0.0942
# Epoch 33/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0945 - val_loss: 0.0947
# Epoch 34/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0946 - val_loss: 0.0943
# Epoch 35/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0944 - val_loss: 0.0940
# Epoch 36/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0943 - val_loss: 0.0940
# Epoch 37/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0945 - val_loss: 0.0939
# Epoch 38/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0942 - val_loss: 0.0939
# Epoch 39/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0943 - val_loss: 0.0938
# Epoch 40/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0941 - val_loss: 0.0940
# Epoch 41/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0941 - val_loss: 0.0938
# Epoch 42/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0941 - val_loss: 0.0941
# Epoch 43/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0940 - val_loss: 0.0941
# Epoch 44/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0941 - val_loss: 0.0939
# Epoch 45/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0941 - val_loss: 0.0938
# Epoch 46/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0940 - val_loss: 0.0939
# Epoch 47/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0940 - val_loss: 0.0940
# Epoch 48/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0939 - val_loss: 0.0935
# Epoch 49/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0939 - val_loss: 0.0938
# Epoch 50/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0939 - val_loss: 0.0937
# Epoch 51/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0937 - val_loss: 0.0937
# Epoch 52/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0939 - val_loss: 0.0937
# Epoch 53/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0936 - val_loss: 0.0935
# Epoch 54/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0937 - val_loss: 0.0937
# Epoch 55/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0937 - val_loss: 0.0934
# Epoch 56/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0935 - val_loss: 0.0934
# Epoch 57/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0939 - val_loss: 0.0935
# Epoch 58/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0936 - val_loss: 0.0934
# Epoch 59/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0935 - val_loss: 0.0933
# Epoch 60/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0935 - val_loss: 0.0936
# Epoch 61/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0936 - val_loss: 0.0934
# Epoch 62/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0935 - val_loss: 0.0935
# Epoch 63/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0935 - val_loss: 0.0932
# Epoch 64/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0936 - val_loss: 0.0936
# Epoch 65/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0936 - val_loss: 0.0937
# Epoch 66/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0933 - val_loss: 0.0932
# Epoch 67/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0935 - val_loss: 0.0934
# Epoch 68/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0935 - val_loss: 0.0936
# Epoch 69/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0934 - val_loss: 0.0933
# Epoch 70/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0934 - val_loss: 0.0933
# Epoch 71/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0933 - val_loss: 0.0933
# Epoch 72/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0933 - val_loss: 0.0931
# Epoch 73/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0933 - val_loss: 0.0940
# Epoch 74/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0933 - val_loss: 0.0937
# Epoch 75/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0933 - val_loss: 0.0934
# Epoch 76/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0932 - val_loss: 0.0931
# Epoch 77/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0932 - val_loss: 0.0933
# Epoch 78/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0932 - val_loss: 0.0933
# Epoch 79/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0933 - val_loss: 0.0931
# Epoch 80/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0932 - val_loss: 0.0931
# Epoch 81/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0932 - val_loss: 0.0933
# Epoch 82/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0932 - val_loss: 0.0930
# Epoch 83/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0933 - val_loss: 0.0931
# Epoch 84/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0932 - val_loss: 0.0937
# Epoch 85/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0933 - val_loss: 0.0931
# Epoch 86/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0931 - val_loss: 0.0933
# Epoch 87/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0932 - val_loss: 0.0930
# Epoch 88/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0933 - val_loss: 0.0930
# Epoch 89/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0930 - val_loss: 0.0932
# Epoch 90/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0932 - val_loss: 0.0932
# Epoch 91/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0930 - val_loss: 0.0932
# Epoch 92/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0930 - val_loss: 0.0932
# Epoch 93/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0932 - val_loss: 0.0938
# Epoch 94/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0931 - val_loss: 0.0930
# Epoch 95/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0932 - val_loss: 0.0930
# Epoch 96/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0931 - val_loss: 0.0932
# Epoch 97/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0932 - val_loss: 0.0931
# Epoch 98/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0930 - val_loss: 0.0934
# Epoch 99/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0932 - val_loss: 0.0931
# Epoch 100/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0931 - val_loss: 0.0930

# %% [markdown]
# Sequence-to-Sequence Autoencoder

# %%
timesteps = ...  # Length of your sequences
input_dim = ... 
latent_dim = ...

inputs = keras.Input(shape=(timesteps, input_dim))
encoded = layers.LSTM(latent_dim)(inputs)

decoded = layers.RepeatVector(timesteps)(encoded)
decoded = layers.LSTM(input_dim, return_sequences=True)(decoded)

sequence_autoencoder = keras.Model(inputs, decoded)
encoder = keras.Model(inputs, encoded)

# %% [markdown]
# Variational Autoencoder (VAE)

# %%
original_dim = 28 * 28
intermediate_dim = 64
latent_dim = 2

inputs = keras.Input(shape=(original_dim,))
h = layers.Dense(intermediate_dim, activation='relu')(inputs)
z_mean = layers.Dense(latent_dim)(h)
z_log_sigma = layers.Dense(latent_dim)(h)

# %%
from keras import backend as K

def sampling(args):
    z_mean, z_log_sigma = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim),
                              mean=0., stddev=0.1)
    return z_mean + K.exp(z_log_sigma) * epsilon

z = layers.Lambda(sampling)([z_mean, z_log_sigma])

# %%
# Create encoder
encoder = keras.Model(inputs, [z_mean, z_log_sigma, z], name='encoder')

# Create decoder
latent_inputs = keras.Input(shape=(latent_dim,), name='z_sampling')
x = layers.Dense(intermediate_dim, activation='relu')(latent_inputs)
outputs = layers.Dense(original_dim, activation='sigmoid')(x)
decoder = keras.Model(latent_inputs, outputs, name='decoder')

# instantiate VAE model
outputs = decoder(encoder(inputs)[2])
vae = keras.Model(inputs, outputs, name='vae_mlp')

# %%
reconstruction_loss = keras.losses.binary_crossentropy(inputs, outputs)
reconstruction_loss *= original_dim
kl_loss = 1 + z_log_sigma - K.square(z_mean) - K.exp(z_log_sigma)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = K.mean(reconstruction_loss + kl_loss)
vae.add_loss(vae_loss)
vae.compile(optimizer='adam')

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

vae.fit(x_train, x_train,
        epochs=100,
        batch_size=32,
        validation_data=(x_test, x_test))
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 8s 3ms/step - loss: 223.3361 - val_loss: 166.5671
# Epoch 2/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 165.4355 - val_loss: 163.0938
# Epoch 3/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 162.3276 - val_loss: 161.1651
# Epoch 4/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 160.2377 - val_loss: 159.3701
# Epoch 5/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 158.2318 - val_loss: 157.7318
# Epoch 6/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 157.0911 - val_loss: 156.6141
# Epoch 7/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 156.1676 - val_loss: 155.7227
# Epoch 8/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 155.1827 - val_loss: 154.8082
# Epoch 9/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 154.4143 - val_loss: 153.9891
# Epoch 10/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 153.5037 - val_loss: 153.8118
# Epoch 11/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 152.7070 - val_loss: 153.1167
# Epoch 12/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 152.2879 - val_loss: 152.7384
# Epoch 13/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 152.0566 - val_loss: 152.3162
# Epoch 14/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 151.9439 - val_loss: 152.0074
# Epoch 15/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 151.2137 - val_loss: 151.8850
# Epoch 16/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 150.9559 - val_loss: 151.6767
# Epoch 17/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 151.0449 - val_loss: 151.3228
# Epoch 18/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 150.5885 - val_loss: 151.1960
# Epoch 19/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 150.3799 - val_loss: 150.9217
# Epoch 20/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 150.1844 - val_loss: 150.9160
# Epoch 21/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 150.0940 - val_loss: 150.5761
# Epoch 22/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 149.7226 - val_loss: 150.5321
# Epoch 23/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 149.3527 - val_loss: 150.4743
# Epoch 24/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 149.3004 - val_loss: 150.2120
# Epoch 25/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 148.7770 - val_loss: 150.2191
# Epoch 26/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 149.0842 - val_loss: 149.9188
# Epoch 27/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 148.9570 - val_loss: 149.8484
# Epoch 28/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 148.4196 - val_loss: 150.0811
# Epoch 29/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 148.0765 - val_loss: 149.6541
# Epoch 30/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 148.1870 - val_loss: 149.7684
# Epoch 31/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 148.2782 - val_loss: 149.3608
# Epoch 32/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 148.1334 - val_loss: 149.7658
# Epoch 33/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 148.3675 - val_loss: 149.2574
# Epoch 34/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 148.0986 - val_loss: 149.4622
# Epoch 35/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 147.9630 - val_loss: 149.1648
# Epoch 36/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 147.7466 - val_loss: 149.0993
# Epoch 37/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 147.8055 - val_loss: 149.0419
# Epoch 38/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 147.6433 - val_loss: 149.2611
# Epoch 39/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 147.3995 - val_loss: 148.9894
# Epoch 40/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 147.3653 - val_loss: 148.7413
# Epoch 41/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 147.3254 - val_loss: 148.9887
# Epoch 42/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 147.2766 - val_loss: 148.7857
# Epoch 43/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 147.1098 - val_loss: 148.6525
# Epoch 44/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 146.9838 - val_loss: 148.8468
# Epoch 45/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 147.0980 - val_loss: 148.6991
# Epoch 46/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 146.7167 - val_loss: 148.6221
# Epoch 47/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.7820 - val_loss: 148.4694
# Epoch 48/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.5243 - val_loss: 148.4991
# Epoch 49/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.8901 - val_loss: 148.4707
# Epoch 50/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.8336 - val_loss: 148.4261
# Epoch 51/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.3453 - val_loss: 148.3281
# Epoch 52/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.4262 - val_loss: 148.4496
# Epoch 53/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.5935 - val_loss: 148.1924
# Epoch 54/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.5192 - val_loss: 148.1968
# Epoch 55/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.4390 - val_loss: 148.0615
# Epoch 56/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.4911 - val_loss: 148.3300
# Epoch 57/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.0135 - val_loss: 148.2744
# Epoch 58/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.1152 - val_loss: 147.9995
# Epoch 59/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.4668 - val_loss: 148.0831
# Epoch 60/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 145.8794 - val_loss: 148.1417
# Epoch 61/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 146.1715 - val_loss: 148.2867
# Epoch 62/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.9862 - val_loss: 148.0982
# Epoch 63/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.0697 - val_loss: 148.1982
# Epoch 64/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.0464 - val_loss: 148.1662
# Epoch 65/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.9653 - val_loss: 147.8737
# Epoch 66/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.7144 - val_loss: 147.7592
# Epoch 67/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.5114 - val_loss: 147.7675
# Epoch 68/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 145.3808 - val_loss: 147.7665
# Epoch 69/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.5473 - val_loss: 147.8321
# Epoch 70/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.0689 - val_loss: 147.7628
# Epoch 71/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.8061 - val_loss: 147.6386
# Epoch 72/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.7672 - val_loss: 147.9053
# Epoch 73/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.7622 - val_loss: 147.7941
# Epoch 74/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.0546 - val_loss: 147.8127
# Epoch 75/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.2858 - val_loss: 147.4333
# Epoch 76/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.6019 - val_loss: 147.8044
# Epoch 77/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 145.3874 - val_loss: 147.6257
# Epoch 78/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.1343 - val_loss: 147.5012
# Epoch 79/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.4846 - val_loss: 147.5434
# Epoch 80/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.8344 - val_loss: 147.5792
# Epoch 81/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.8096 - val_loss: 147.5937
# Epoch 82/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.8689 - val_loss: 147.6190
# Epoch 83/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.9282 - val_loss: 147.5898
# Epoch 84/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.7000 - val_loss: 147.3202
# Epoch 85/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.7558 - val_loss: 147.4523
# Epoch 86/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.0596 - val_loss: 147.1839
# Epoch 87/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.6697 - val_loss: 147.3230
# Epoch 88/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.0298 - val_loss: 147.4113
# Epoch 89/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 144.6214 - val_loss: 147.1771
# Epoch 90/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.4969 - val_loss: 147.1357
# Epoch 91/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.9320 - val_loss: 147.4789
# Epoch 92/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.5247 - val_loss: 147.2121
# Epoch 93/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 144.5985 - val_loss: 147.3443
# Epoch 94/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 144.6326 - val_loss: 147.2529
# Epoch 95/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 144.5459 - val_loss: 147.2171
# Epoch 96/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.4197 - val_loss: 147.8790
# Epoch 97/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.3200 - val_loss: 147.1442
# Epoch 98/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.3961 - val_loss: 147.0624
# Epoch 99/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.7279 - val_loss: 146.9836
# Epoch 100/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.4010 - val_loss: 147.4738

# %%
x_test_encoded = encoder.predict(x_test, batch_size=32)
plt.figure(figsize=(6, 6))
plt.scatter(x_test_encoded[:, 0], x_test_encoded[:, 1], c=y_test)
plt.colorbar()
plt.show()

# %%
# Display a 2D manifold of the digits
n = 15  # figure with 15x15 digits
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
# We will sample n points within [-15, 15] standard deviations
grid_x = np.linspace(-15, 15, n)
grid_y = np.linspace(-15, 15, n)

for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        x_decoded = decoder.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure)
plt.show()
